# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
CryptoClose = pd.read_csv("CryptoClose.csv",index_col=[0],parse_dates=[0])

# %%
CryptoClose
# Out:
#                  BTC-USD      ETH-USD    LTC-USD
# Date
# 2017-11-09   7143.580078   320.884003  64.269699
# 2017-11-10   6618.140137   299.252991  59.260101
# 2017-11-11   6357.600098   314.681000  62.303299
# 2017-11-12   5950.069824   307.907990  59.005402
# 2017-11-13   6559.490234   316.716003  61.396500
# ...                  ...          ...        ...
# 2022-07-12  19323.914062  1038.191650  47.542385
# 2022-07-13  20212.074219  1113.587158  49.563126
# 2022-07-14  20569.919922  1191.526245  51.218807
# 2022-07-15  20836.328125  1233.129150  51.798065
# 2022-07-16  21190.316406  1352.626465  55.125164
#
# [1711 rows x 3 columns]

# %%
CryptoClose.plot(figsize=(15,8),fontsize=13)
plt.legend(fontsize=13)
plt.show()

# %%
CryptoClose.iloc[0]
# Out:
# BTC-USD    7143.580078
# ETH-USD     320.884003
# LTC-USD      64.269699
# Name: 2017-11-09 00:00:00, dtype: float64

# %%
norm=CryptoClose.div(CryptoClose.iloc[0]).mul(100)

# %%
norm
# Out:
#                BTC-USD     ETH-USD     LTC-USD
# Date
# 2017-11-09  100.000000  100.000000  100.000000
# 2017-11-10   92.644585   93.258931   92.205351
# 2017-11-11   88.997394   98.066902   96.940393
# 2017-11-12   83.292547   95.956167   91.809052
# 2017-11-13   91.823570   98.701088   95.529465
# ...                ...         ...         ...
# 2022-07-12  270.507419  323.541106   73.973250
# 2022-07-13  282.940402  347.037294   77.117407
# 2022-07-14  287.949735  371.326160   79.693554
# 2022-07-15  291.679073  384.291252   80.594846
# 2022-07-16  296.634407  421.531287   85.771623
#
# [1711 rows x 3 columns]

# %%
norm.plot(figsize=(15,8),fontsize=13)
plt.legend(fontsize=13)
plt.show()
